# %%
import random
import numpy as np
import time

# %%
matrix1 = [[random.randint(0, 1) for _ in range(100)] for _ in range(100)]
matrix2 = [[random.randint(0, 1) for _ in range(100)] for _ in range(100)]
vector1 = [random.randint(0, 1) for _ in range(100)]
vector2 = [random.randint(0, 1) for _ in range(100)]

# %%
def Numpy(array1, array2):
    return np.dot(array1, array2).tolist()

# %%
def matrix_x_matrix(matrix1, matrix2):
    result = [[0 for _ in range(len(matrix2[0]))] for _ in range(len(matrix1))]
    for i in range(len(matrix1)):
        for j in range(len(matrix2[0])):
            for k in range(len(matrix2)):
                result[i][j] += matrix1[i][k] * matrix2[k][j]
    return result

# %%
startTime = time.time()
matrix_x_matrix(matrix1, matrix2)
endTime = time.time()
resTime = endTime-startTime
print(f'Час без використання Numpy: {resTime}')

startTime = time.time()
Numpy(matrix1, matrix2)
endTime = time.time()
resTime = endTime-startTime
print(f'Час з використання Numpy: {resTime}')
# Out:
# Час без використання Numpy: 0.28766751289367676
# Час з використання Numpy: 0.0037963390350341797

# %%
def matrix_x_vector(matrix, vector):
    result = [0 for _ in range(len(matrix))]
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            result[i] += matrix[i][j] * vector[j]
    return result

# %%
startTime = time.time()
matrix_x_vector(matrix1, vector1)
endTime = time.time()
resTime = endTime-startTime
print(f'Час без використання Numpy: {resTime}')

startTime = time.time()
Numpy(matrix1, vector1)
endTime = time.time()
resTime = endTime-startTime
print(f'Час з використання Numpy: {resTime}')
# Out:
# Час без використання Numpy: 0.0025103092193603516
# Час з використання Numpy: 0.0014743804931640625

# %%
def vector_x_matrix(vector, matrix):
    result = [0 for i in range(len(vector))]
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            result[i] += matrix[j][i] * vector[j]
    return result

# %%
startTime = time.time()
vector_x_matrix(vector1, matrix1)
endTime = time.time()
resTime = endTime-startTime
print(f'Час без використання Numpy: {resTime}')

startTime = time.time()
Numpy(vector1, matrix1)
endTime = time.time()
resTime = endTime-startTime
print(f'Час з використання Numpy: {resTime}')
# Out:
# Час без використання Numpy: 0.004667758941650391
# Час з використання Numpy: 0.0026268959045410156

# %%
def vector_x_vector(vector1, vector2):
    result = 0
    for i in range(len(vector1)):
        result += vector1[i]*vector2[i]
    return result

# %%
startTime = time.time()
vector_x_vector(vector1, vector2)
endTime = time.time()
resTime = endTime-startTime
print(f'Час без використання Numpy: {resTime}')

startTime = time.time()
Numpy(vector1, vector2)
endTime = time.time()
resTime = endTime-startTime
print(f'Час з використання Numpy: {resTime}')
# Out:
# Час без використання Numpy: 7.009506225585938e-05
# Час з використання Numpy: 0.00012993812561035156
